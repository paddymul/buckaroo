# %%
# !ls -alshtr "/Users/paddy/JULY_FULL.parq"

# %%
# 9M rows 330 columns

# %%
from buckaroo.file_cache import cache_utils as cu
cu.clear_file_cache()
read("/Users/paddy/JULY_FULL.parq", show_message_box=True, timeout_secs=25.0)

# %%
1+1

# %%
from buckaroo.read_utils import read_df, read
import polars as pl
read_df("/Users/paddy/JULY_FULL.parq").select(pl.col('NPI').len()).collect()
